# %%
import pandas as pd

# %% [markdown]
# ### 메이커 스페이스 방문 데이터 분석 3월달
# ##### 메이커스페이스 입구에서 계속적으로

# %%
df = pd.read_csv("making_space.csv", encoding="utf-8") # "created_at"
df.head()
df.tail()
# Out:
#                     created_at  entry_id  field1  field2  field3  field4  \
# 41594  2021-04-15 13:00:10 KST     41595       0  209.41    22.4    30.1
# 41595  2021-04-15 13:01:09 KST     41596       0  209.58    22.4    29.9
# 41596  2021-04-15 13:02:08 KST     41597       0  209.47    22.4    30.2
# 41597  2021-04-15 13:03:07 KST     41598       0  209.07    22.3    30.4
# 41598  2021-04-15 13:04:06 KST     41599       0  209.49    22.4    30.6
#
#        latitude  longitude  elevation  status
# 41594       NaN        NaN        NaN     NaN
# 41595       NaN        NaN        NaN     NaN
# 41596       NaN        NaN        NaN     NaN
# 41597       NaN        NaN        NaN     NaN
# 41598       NaN        NaN        NaN     NaN

# %%
df.groupby("created_at").sum()["field1"].plot.line()
# Out:
# <AxesSubplot:xlabel='created_at'>

# %% [markdown]
# #### datatime 셋으로 "created_at"을 스템프 찍는다.

# %%
temp = pd.to_datetime(df['created_at']) #
# Out:
# C:\Users\uskaw\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1213: UnknownTimezoneWarning: tzname KST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "

# %%
df.index = temp

# %%
df.dtypes
# Out:
# created_at     object
# entry_id        int64
# field1          int64
# field2        float64
# field3        float64
# field4        float64
# latitude      float64
# longitude     float64
# elevation     float64
# status        float64
# dtype: object

# %%
df["2021-03-16"].sum()
df_renew = pd.DataFrame(columns=["created_at", "field1"])
df_renew
# Out:
# Empty DataFrame
# Columns: [created_at, field1]
# Index: []

# %%
list = []
list2=[]
df_renew = pd.DataFrame()
df_renew = pd.DataFrame(columns=["created_at", "field1"])
for c in range(3, 5):
    for d in range(1,31):
        for h in range(0,24):
            if len(str(h)) != 2 :
                h = "0" + str(h)  # df_renew["created_at"] +=

            try :
                list2.append(df["2021-0" + str(c) + "-"+str(d)+" "+str(h)].sum()['field1']) # ['created_at']
                list.append("2021-03-"+str(d)+" "+str(h))
            except :
                pass

df_renew["field1"] = list2
df_renew.index = pd.to_datetime(list)
df_renew
# list
# Out:
#                     created_at  field1
# 2021-03-12 14:00:00        NaN    21.0
# 2021-03-12 15:00:00        NaN    16.0
# 2021-03-12 16:00:00        NaN    19.0
# 2021-03-12 17:00:00        NaN    13.0
# 2021-03-12 18:00:00        NaN     5.0
# ...                        ...     ...
# 2021-03-15 09:00:00        NaN     0.0
# 2021-03-15 10:00:00        NaN     0.0
# 2021-03-15 11:00:00        NaN     0.0
# 2021-03-15 12:00:00        NaN     1.0
# 2021-03-15 13:00:00        NaN     0.0
#
# [792 rows x 2 columns]

# %% [markdown]
# #### 데이터 시각화

# %%
df_renew["field1"].plot.line(figsize=(20,10), marker="*")
# Out:
# <AxesSubplot:>

# %%
weather = pd.read_csv("춘천_3월_날씨.csv", encoding="cp949" )

# %%
weather.head()
# Out:
#     지점 지점명                일시  기온(°C)  강수량(mm)  풍속(m/s)  습도(%)  일조(hr)  \
# 0  101  춘천  2021-03-01 01:00     5.7      NaN      0.9     59     NaN
# 1  101  춘천  2021-03-01 02:00     5.7      NaN      0.2     60     NaN
# 2  101  춘천  2021-03-01 03:00     5.2      0.2      0.3     80     NaN
# 3  101  춘천  2021-03-01 04:00     5.1      NaN      1.7     77     NaN
# 4  101  춘천  2021-03-01 05:00     4.9      NaN      1.1     83     NaN
#
#    전운량(10분위)
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
weather['일시'] = pd.to_datetime(weather["일시"])

# %%
weather
# Out:
#       지점 지점명                  일시  기온(°C)  강수량(mm)  풍속(m/s)  습도(%)  일조(hr)  \
# 0    101  춘천 2021-03-01 01:00:00     5.7      NaN      0.9     59     NaN
# 1    101  춘천 2021-03-01 02:00:00     5.7      NaN      0.2     60     NaN
# 2    101  춘천 2021-03-01 03:00:00     5.2      0.2      0.3     80     NaN
# 3    101  춘천 2021-03-01 04:00:00     5.1      NaN      1.7     77     NaN
# 4    101  춘천 2021-03-01 05:00:00     4.9      NaN      1.1     83     NaN
# ..   ...  ..                 ...     ...      ...      ...    ...     ...
# 835  101  춘천 2021-04-04 20:00:00     9.1      NaN      2.4     54     NaN
# 836  101  춘천 2021-04-04 21:00:00     8.0      NaN      1.2     58     NaN
# 837  101  춘천 2021-04-04 22:00:00     7.4      NaN      1.7     62     NaN
# 838  101  춘천 2021-04-04 23:00:00     6.3      NaN      1.4     66     NaN
# 839  101  춘천 2021-04-05 00:00:00     5.7      NaN      1.9     70     NaN
#
#      전운량(10분위)
# 0          NaN
# 1          NaN
# 2          NaN
# ...

# %%
weather.groupby("일시")['기온(°C)'].sum().plot.line()
# Out:
# <AxesSubplot:xlabel='일시'>
# C:\Users\uskaw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\uskaw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\uskaw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\uskaw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df_renew["field1"].plot.line(figsize=(20,10), marker="*")
# weather.groupby("일시")['기온(°C)'].sum().plot.line()
weather.groupby("일시")['풍속(m/s)'].sum().plot.line()
# Out:
# <AxesSubplot:xlabel='일시'>
# C:\Users\uskaw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\uskaw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\uskaw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\uskaw\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
list = []
list2=[]
df_renew = pd.DataFrame()
df_renew = pd.DataFrame(columns=["created_at", "field1"])
for c in range(3, 5):
    for d in range(1,31):
            try :
                list2.append(df["2021-0" + str(c) + "-"+str(d)].sum()['field1']) # ['created_at']
                list.append("2021-0"+ str(c) + "-"+str(d))
            except :
                pass

df_renew["field1"] = list2
df_renew.index = pd.to_datetime(list)
df_renew
# list
# Out:
#            created_at  field1
# 2021-03-12        NaN    74.0
# 2021-03-13        NaN     2.0
# 2021-03-14        NaN     0.0
# 2021-03-15        NaN    87.0
# 2021-03-16        NaN    70.0
# 2021-03-17        NaN   155.0
# 2021-03-18        NaN   181.0
# 2021-03-19        NaN   114.0
# 2021-03-20        NaN     0.0
# 2021-03-21        NaN     0.0
# 2021-03-22        NaN   223.0
# 2021-03-23        NaN    96.0
# 2021-03-24        NaN   157.0
# 2021-03-25        NaN   120.0
# 2021-03-26        NaN   192.0
# 2021-03-27        NaN    33.0
# 2021-03-28        NaN     4.0
# 2021-03-29        NaN   237.0
# 2021-03-30        NaN   252.0
# 2021-04-01        NaN   132.0
# 2021-04-02        NaN     0.0
# 2021-04-03        NaN     0.0
# 2021-04-04        NaN     0.0
# 2021-04-05        NaN   131.0
# 2021-04-06        NaN   282.0
# 2021-04-07        NaN   124.0
# 2021-04-08        NaN    99.0
# 2021-04-09        NaN   100.0
# 2021-04-10        NaN     9.0
# 2021-04-11        NaN     8.0
# ...

# %%
df_renew["field1"].plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
weather["일시"]
# Out:
# 0     2021-03-01 01:00:00
# 1     2021-03-01 02:00:00
# 2     2021-03-01 03:00:00
# 3     2021-03-01 04:00:00
# 4     2021-03-01 05:00:00
#               ...
# 835   2021-04-04 20:00:00
# 836   2021-04-04 21:00:00
# 837   2021-04-04 22:00:00
# 838   2021-04-04 23:00:00
# 839   2021-04-05 00:00:00
# Name: 일시, Length: 840, dtype: datetime64[ns]

# %%
weather[(weather["일시"] <= '2021-03-01 18:00:00') & (weather["일시"] >= '2021-03-01 09:00:00')]["기온(°C)"].mean()
# Out:
# 3.6800000000000006

# %%
list = []
list2=[]
wether_C = pd.DataFrame()
wether_C = pd.DataFrame(columns=["기온"])
for c in range(3, 5):
    for d in range(1,31):
        if((c == 3) &  (d < 12)):
            continue
        try :
            list2.append(weather[(weather["일시"] <= '2021-0' + str(c) +'-'+ str(d) + ' 18:00:00') & (weather["일시"] >= '2021-0' + str(c) +'-'+ str(d)+' 09:00:00')]["기온(°C)"].mean()) # ['created_at']
            list.append("2021-0"+ str(c) + "-"+str(d))
        except :
            pass

wether_C["기온"] = list2
wether_C.index = pd.to_datetime(list)
wether_C
# list
# Out:
#                기온
# 2021-03-12  10.48
# 2021-03-13  12.12
# 2021-03-14  11.93
# 2021-03-15  11.44
# 2021-03-16  13.11
# 2021-03-17  13.39
# 2021-03-18  14.23
# 2021-03-19  16.63
# 2021-03-20   9.74
# 2021-03-21   8.21
# 2021-03-22   9.50
# 2021-03-23  12.34
# 2021-03-24  13.18
# 2021-03-25  15.89
# 2021-03-26  16.70
# 2021-03-27  11.62
# 2021-03-28  10.73
# 2021-03-29  13.88
# 2021-03-30  15.16
# 2021-04-01  18.90
# 2021-04-02  20.81
# 2021-04-03  13.33
# 2021-04-04  11.58
# 2021-04-05    NaN
# 2021-04-06    NaN
# 2021-04-07    NaN
# 2021-04-08    NaN
# 2021-04-09    NaN
# 2021-04-10    NaN
# 2021-04-11    NaN
# 2021-04-12    NaN
# 2021-04-13    NaN
# 2021-04-14    NaN
# 2021-04-15    NaN
# 2021-04-16    NaN
# 2021-04-17    NaN
# 2021-04-18    NaN
# 2021-04-19    NaN
# 2021-04-20    NaN
# 2021-04-21    NaN
# 2021-04-22    NaN
# 2021-04-23    NaN
# 2021-04-24    NaN
# 2021-04-25    NaN
# 2021-04-26    NaN
# 2021-04-27    NaN
# 2021-04-28    NaN
# 2021-04-29    NaN
# 2021-04-30    NaN

# %%
weather_C = wether_C.dropna()

# %%
import matplotlib.pyplot as plt

# %%
weather_C['기온'].plot.bar(figsize=(20,10)) #, marker="*", color="red"

df_renew["field1"].plot.bar(figsize=(20,10), color ="red")
# Out:
# <AxesSubplot:>

# %%
plt.plot(weather_C.index, weather_C['기온'])

# %%
fig , ax1 = plt.subplots()
# fig.figure(figsize=(20,10))
ax1.bar(df_renew.index, df_renew["field1"])
ax2 = ax1.twinx()
ax2.plot(weather_C.index, weather_C['기온'], color = "red")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-208-f9774f2d90e2> in <module>
#       1 fig , ax1 = plt.subplots()
#       2 # fig.figure(figsize=(20,10))
# ----> 3 ax1.bar(df_renew.index, df_renew["field1"], figsize=(20,10))
#       4 ax2 = ax1.twinx()
#       5 ax2.plot(weather_C.index, weather_C['기온'], color = "red")
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2486                 label='_nolegend_',
#    2487                 )
# ...

# %%
weather_C['기온'].plot(figsize=(20,10), marker="*", color="red")
# Out:
# <AxesSubplot:>
